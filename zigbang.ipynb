# %%
import requests
import time
import pandas as pd
from typing import List, Dict
from pygeohash import encode as geohash_encode  # pip install pygeohash


class ZigbangAPI:
    BASE_LIST_URL = "https://apis.zigbang.com/v2/items/{roomtype}"
    BASE_DETAIL_URL_V3 = "https://apis.zigbang.com/v3/items/{item_id}"

    def __init__(self, lat_center: float, lng_center: float, room_type: str, delta: float = 0.003):
        self.lat_center = lat_center
        self.lng_center = lng_center
        self.delta = delta
        self.lat_south = lat_center - delta
        self.lat_north = lat_center + delta
        self.lng_west = lng_center - delta
        self.lng_east = lng_center + delta
        self.room_type = room_type

    def _calculate_geohash(self) -> str:
        return geohash_encode(self.lat_center, self.lng_center, precision=5)

    def get_item_ids(self) -> List[int]:
        geohash = self._calculate_geohash()
        url = self.BASE_LIST_URL.format(roomtype=self.room_type)
        params = {
            "geohash": geohash,
            "latSouth": self.lat_south,
            "latNorth": self.lat_north,
            "lngWest": self.lng_west,
            "lngEast": self.lng_east,
            "domain": "zigbang",
            "checkAnyItemWithoutFilter": True
        }
        response = requests.get(url, params=params)
        print(f"[{self.room_type}] 매물 ID 요청 URL:", response.url)
        response.raise_for_status()
        items = response.json().get("items", [])
        return [item["itemId"] for item in items]

    def get_item_details_v3(self, item_ids: List[int]) -> List[Dict]:
        details = []
        for item_id in item_ids:
            url = self.BASE_DETAIL_URL_V3.format(item_id=item_id)
            params = {"version": "", "domain": "zigbang"}
            response = requests.get(url, params=params)
            print(f"[{self.room_type}] 개별 매물 상세 요청 URL: {response.url}")
            if response.status_code == 200:
                result = response.json()
                item = result.get("item", {})
                if item:
                    lat = item.get("location", {}).get("lat")
                    lng = item.get("location", {}).get("lng")
                    if lat and lng and self.lat_south <= lat <= self.lat_north and self.lng_west <= lng <= self.lng_east:
                        detail = {
                            "매물ID": item.get("itemId"),
                            "사이트": "직방",
                            "주소": item.get("jibunAddress"),
                            "세부 URL": f"https://www.zigbang.com/home/{self.room_type}/items/{item.get('itemId')}",
                            "유형": item.get("salesType"),
                            "보증금": item.get("price", {}).get("deposit"),
                            "월세": item.get("price", {}).get("rent"),
                            "관리비": item.get("manageCost", {}).get("amount"),
                            "관리비 포함": ', '.join(item.get("manageCost", {}).get("includes", [])),
                            "면적(m²)": item.get("area", {}).get("전용면적M2"),
                            "면적(평)": round(item.get("area", {}).get("전용면적M2", 0) / 3.3058, 2),
                            "형식": item.get("roomType"),
                            "층수": f"{item.get('floor', {}).get('floor')}층 / {item.get('floor', {}).get('allFloors')}층",
                            "등록번호": item.get("itemId")
                        }
                        details.append(detail)
            else:
                print(f"매물 ID {item_id} 조회 실패 (status: {response.status_code})")
            time.sleep(0.2)
        return details


class ZigbangDataProcessor:
    @staticmethod
    def to_dataframe(items: List[Dict]) -> pd.DataFrame:
        return pd.DataFrame(items)

if __name__ == "__main__":
    lat_center = 37.48066
    lng_center = 126.89341

    room_types = [ 'villa', 'oneroom', 'officetel' ] # 'apt'
    all_dataframes = []

    for room in room_types:
        print(f"\n매물 유형: {room}")
        api = ZigbangAPI(lat_center, lng_center, room_type=room, delta=0.003)
        try:
            item_ids = api.get_item_ids()
            print(f"{room} 매물 개수: {len(item_ids)}")
            details = api.get_item_details_v3(item_ids[:10])  # 테스트로 10개만
            df = ZigbangDataProcessor.to_dataframe(details)
version=&domain=zigbang
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44437469?version=&domain=zigbang
#
# 매물 유형: oneroom
# [oneroom] 매물 ID 요청 URL: https://apis.zigbang.com/v2/items/oneroom?geohash=wydjp&latSouth=37.47766&latNorth=37.48366&lngWest=126.89041&lngEast=126.89641&domain=zigbang&checkAnyItemWithoutFilter=True
# oneroom 매물 개수: 976
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44299204?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44222460?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44408843?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44463553?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44270496?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44311520?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44368384?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44416979?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44362737?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44404807?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44527143?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44211564?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44225734?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44256592?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44522451?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44491320?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44491303?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44358010?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44480870?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44506621?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44317508?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44408960?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44509792?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44510635?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44524832?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44511116?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44511529?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44414149?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44529547?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44404830?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44267141?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44529381?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44400499?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44480236?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44520280?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44520980?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44521159?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44357605?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44450467?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44447077?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44216027?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44465755?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44496355?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44459625?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44480660?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44514239?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44514263?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44331241?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44464614?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44510037?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44493250?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44404814?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44427544?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44504740?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44504758?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44504777?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44291983?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44379810?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44497893?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44496351?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/40863932?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/40864012?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/40864091?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43992681?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43992709?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44032833?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44490062?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44374187?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44454131?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44529460?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43694465?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44361337?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44388481?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44255481?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43318159?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44523018?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44509580?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/39744479?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43022298?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44075598?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44330622?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44427974?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44486810?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44485899?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/42929140?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44506419?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44529117?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44325171?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44527282?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43869188?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44193105?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44442655?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44526854?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44527410?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44457326?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/43945039?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44257595?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44257642?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44257675?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44294207?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44391050?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44416343?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44416655?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44473483?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44482493?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44482580?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44483343?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44498040?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44498122?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44498270?version=&domain=zigbang

# %%
import requests
import time
import pandas as pd
from typing import List, Dict
from pygeohash import encode as geohash_encode  # pip install pygeohash


class ZigbangAPI:
    BASE_LIST_URL = "https://apis.zigbang.com/v2/items/{roomtype}"
    BASE_DETAIL_URL_V3 = "https://apis.zigbang.com/v3/items/{item_id}"

    def __init__(self, lat_center: float, lng_center: float, room_type: str, delta: float = 0.003):
        self.lat_center = lat_center
        self.lng_center = lng_center
        self.delta = delta
        self.lat_south = lat_center - delta
        self.lat_north = lat_center + delta
        self.lng_west = lng_center - delta
        self.lng_east = lng_center + delta
        self.room_type = room_type

    def _calculate_geohash(self) -> str:
        # 중심 좌표로 geohash 생성 (정확도: 5)
        return geohash_encode(self.lat_center, self.lng_center, precision=5)

    def _is_within_bounds(self, lat: float, lng: float) -> bool:
        # 위경도가 None이면 False 반환, 아니면 설정 범위 내인지 확인
        if lat is None or lng is None:
            return False
        return self.lat_south <= lat <= self.lat_north and self.lng_west <= lng <= self.lng_east

    def get_item_ids(self) -> List[int]:
        # geohash와 좌표 범위로 매물 ID 목록 요청 후 위경도 필터링
        geohash = self._calculate_geohash()
        url = self.BASE_LIST_URL.format(roomtype=self.room_type)
        params = {
            "geohash": geohash,
            "latSouth": self.lat_south,
            "latNorth": self.lat_north,
            "lngWest": self.lng_west,
            "lngEast": self.lng_east,
            "domain": "zigbang",
            "checkAnyItemWithoutFilter": True
        }
        response = requests.get(url, params=params)
        print(f"[{self.room_type}] 매물 ID 요청 URL:", response.url)
        response.raise_for_status()
        items = response.json().get("items", [])

        # 위경도 필터링 적용
        return [item["itemId"] for item in items if self._is_within_bounds(item.get("lat"), item.get("lng"))]

    def get_item_details_v3(self, item_ids: List[int]) -> List[Dict]:
        details = []
        for item_id in item_ids:
            url = self.BASE_DETAIL_URL_V3.format(item_id=item_id)
            params = {"version": "", "domain": "zigbang"}
            try:
                response = requests.get(url, params=params)
                # print(f"[{self.room_type}] 개별 매물 상세 요청 URL: {response.url}")
                response.raise_for_status()
            except requests.RequestException as e:
                print(f"매물 ID {item_id} 요청 실패: {e}")
                continue

            result = response.json()
            item = result.get("item", {})

            if item:
                item_id = item.get("itemId")
                price = item.get("price", {})
                area = item.get("area", {})
                floor_info = item.get("floor", {})
                manage_cost = item.get("manageCost", {})

                detail = {
                    "매물ID": item_id,
                    "사이트": "직방",
                    "주소": item.get("jibunAddress"),
                    "세부 URL": f"https://www.zigbang.com/home/{self.room_type}/items/{item_id}",
                    "유형": item.get("salesType"),
                    "보증금": price.get("deposit"),
                    "월세": price.get("rent"),
                    "관리비": manage_cost.get("amount"),
                    "관리비 포함": ', '.join(manage_cost.get("includes", [])),
                    "면적(m²)": area.get("전용면적M2"),
                    "면적(평)": round(area.get("전용면적M2", 0) / 3.3058, 2),
                    "형식": item.get("roomType"),
                    "층수": f"{floor_info.get('floor')}층 / {floor_info.get('allFloors')}층",
                    "등록번호": item_id
                }
                details.append(detail)

            time.sleep(0.2)  # 서버 과부하 방지용 대기
        return details


class ZigbangDataProcessor:
    @staticmethod
    def to_dataframe(items: List[Dict]) -> pd.DataFrame:
        # 결과를 pandas DataFrame으로 변환
        return pd.DataFrame(items)

if __name__ == "__main__":
    lat_center = 37.48066
    lng_center = 126.89341

    room_types = [ 'villa', 'oneroom', 'officetel' ] # 'apt',
    all_df = []

    for room in room_types:
        print(f"\n매물 유형: {room}")
        api = ZigbangAPI(lat_center, lng_center, room_type=room, delta=0.002)
        try:
            item_ids = api.get_item_ids()
            print(f"{room} 필터링된 매물 개수: {len(item_ids)}")
            details = api.get_item_details_v3(item_ids)
            df = ZigbangDataProcessor.to_dataframe(details)
            all_df.append(df)
        except Exception as e:
            print(f"{room} 오류 발생: {e}")

    if all_df:
        final_df = pd.concat(all_df, ignore_index=True)
        final_df.to_csv("zigbang_selected_info.csv", index=False)
        print("\n저장 완료: zigbang_selected_info.csv")
# Out:
# 매물 유형: villa
# [villa] 매물 ID 요청 URL: https://apis.zigbang.com/v2/items/villa?geohash=wydjp&latSouth=37.47866&latNorth=37.48266&lngWest=126.89141000000001&lngEast=126.89541&domain=zigbang&checkAnyItemWithoutFilter=True
# villa 필터링된 매물 개수: 6
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44450633?version=&domain=zigbang
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44507927?version=&domain=zigbang
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44507994?version=&domain=zigbang
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44362852?version=&domain=zigbang
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44516619?version=&domain=zigbang
# [villa] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44266928?version=&domain=zigbang
#
# 매물 유형: oneroom
# [oneroom] 매물 ID 요청 URL: https://apis.zigbang.com/v2/items/oneroom?geohash=wydjp&latSouth=37.47866&latNorth=37.48266&lngWest=126.89141000000001&lngEast=126.89541&domain=zigbang&checkAnyItemWithoutFilter=True
# oneroom 필터링된 매물 개수: 20
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44103752?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44361321?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44488528?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44488947?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44488981?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44519579?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44493253?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44505530?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44183997?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44287018?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44380000?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44489366?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44493216?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44512699?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44370554?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44397840?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44478182?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44477194?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44084652?version=&domain=zigbang
# [oneroom] 개별 매물 상세 요청 URL: https://apis.zigbang.com/v3/items/44466898?version=&domain=zigbang
#
# 매물 유형: officetel
# [officetel] 매물 ID 요청 URL: https://apis.zigbang.com/v2/items/officetel?geohash=wydjp&latSouth=37.47866&latNorth=37.48266&lngWest=126.89141000000001&lngEast=126.89541&domain=zigbang&checkAnyItemWithoutFilter=True
# officetel 필터링된 매물 개수: 0
#
# 저장 완료: zigbang_selected_info.csv
